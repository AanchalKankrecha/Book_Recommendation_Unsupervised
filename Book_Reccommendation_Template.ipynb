# %% [markdown]
# <a href="https://colab.research.google.com/github/AanchalKankrecha/Book_Recommendation_Unsupervised/blob/main/Book_Reccommendation_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import scipy
import math
import random
import sklearn
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
df1=pd.read_csv('/content/drive/MyDrive/Unsupervised ML/Books.csv')

# %%
df2=pd.read_csv('/content/drive/MyDrive/Unsupervised ML/Ratings.csv')

# %%
df3=pd.read_csv('/content/drive/MyDrive/Unsupervised ML/Users.csv')

# %% [markdown]
# ### Dataset First View

# %%
df1.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
df2.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df3.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
# Dataset First Look

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape,df2.shape,df3.shape
# Out:
# ((271360, 8), (1149780, 3), (278858, 3))

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
# Missing Values/Null Values Count

# %% [markdown]
# No null values in the dataset

# %%
df1.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# freq                                                    2
#
#                                               Image-URL-L
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/225307649X.0...
# freq                                                    2

# %%
df2.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
df3.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
df3.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df1.columns:
  print(f"Unique values in {i} in books dataset")
  print(df1[i].unique())
  print('______'*25)
  print(f"Unique value count in {i} in books dataset")
  print(df1[i].value_counts())
  print('______'*25)
  print('______'*25)
# Out:
# Unique values in ISBN in books dataset
# ['0195153448' '0002005018' '0060973129' ... '006008667X' '0192126040'
#  '0767409752']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in ISBN in books dataset
# 0195153448    1
# 0746008481    1
# 0395219906    1
# 043916169X    1
# 0879235322    1
#              ..
# 1568303823    1
# 0525947612    1
# 207036819X    1
# 2877306127    1
# 0767409752    1
# Name: ISBN, Length: 271360, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Book-Title in books dataset
# ['Classical Mythology' 'Clara Callan' 'Decision in Normandy' ...
#  'Lily Dale : The True Story of the Town that Talks to the Dead'
#  "Republic (World's Classics)"
#  "A Guided Tour of Rene Descartes' Meditations on First Philosophy with Complete Translations of the Meditations by Ronald Rubin"]
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Book-Title in books dataset
# Selected Poems                                                                                                                    27
# Little Women                                                                                                                      24
# Wuthering Heights                                                                                                                 21
# The Secret Garden                                                                                                                 20
# Dracula                                                                                                                           20
#                                                                                                                                   ..
# What Every Kid Should Know                                                                                                         1
# The Seventh Enemy (A Brady Coyne Mystery)                                                                                          1
# A Brace of Skeet                                                                                                                   1
# The Yellow Admiral (O'Brian, Patrick, Aubrey/Maturin Novels, 18.)                                                                  1
# A Guided Tour of Rene Descartes' Meditations on First Philosophy with Complete Translations of the Meditations by Ronald Rubin     1
# Name: Book-Title, Length: 242135, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Book-Author in books dataset
# ['Mark P. O. Morford' 'Richard Bruce Wright' "Carlo D'Este" ...
#  'David Biggs' 'Teri Sloat' 'Christopher  Biffle']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Book-Author in books dataset
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# Linda Jackson             1
# Artiste C. Arthur         1
# Emily Pearl Kingsley      1
# Jean Cassels              1
# Christopher  Biffle       1
# Name: Book-Author, Length: 102023, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Year-Of-Publication in books dataset
# [2002 2001 1991 1999 2000 1993 1996 1988 2004 1998 1994 2003 1997 1983
#  1979 1995 1982 1985 1992 1986 1978 1980 1952 1987 1990 1981 1989 1984 0
#  1968 1961 1958 1974 1976 1971 1977 1975 1965 1941 1970 1962 1973 1972
#  1960 1966 1920 1956 1959 1953 1951 1942 1963 1964 1969 1954 1950 1967
#  2005 1957 1940 1937 1955 1946 1936 1930 2011 1925 1948 1943 1947 1945
#  1923 2020 1939 1926 1938 2030 1911 1904 1949 1932 1928 1929 1927 1931
#  1914 2050 1934 1910 1933 1902 1924 1921 1900 2038 2026 1944 1917 1901
#  2010 1908 1906 1935 1806 2021 '2000' '1995' '1999' '2004' '2003' '1990'
#  '1994' '1986' '1989' '2002' '1981' '1993' '1983' '1982' '1976' '1991'
#  '1977' '1998' '1992' '1996' '0' '1997' '2001' '1974' '1968' '1987' '1984'
#  '1988' '1963' '1956' '1970' '1985' '1978' '1973' '1980' '1979' '1975'
#  '1969' '1961' '1965' '1939' '1958' '1950' '1953' '1966' '1971' '1959'
#  '1972' '1955' '1957' '1945' '1960' '1967' '1932' '1924' '1964' '2012'
#  '1911' '1927' '1948' '1962' '2006' '1952' '1940' '1951' '1931' '1954'
#  '2005' '1930' '1941' '1944' 'DK Publishing Inc' '1943' '1938' '1900'
#  '1942' '1923' '1920' '1933' 'Gallimard' '1909' '1946' '2008' '1378'
#  '2030' '1936' '1947' '2011' '2020' '1919' '1949' '1922' '1897' '2024'
#  '1376' '1926' '2037']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Year-Of-Publication in books dataset
# 2002    13903
# 2001    13715
# 1999    13414
# 2000    13373
# 1998    12116
#         ...
# 1924        1
# 2012        1
# 1927        1
# 1931        1
# 2037        1
# Name: Year-Of-Publication, Length: 202, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Publisher in books dataset
# ['Oxford University Press' 'HarperFlamingo Canada' 'HarperPerennial' ...
#  'Tempo' 'Life Works Books' 'Connaught']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Publisher in books dataset
# Harlequin                  7535
# Silhouette                 4220
# Pocket                     3905
# Ballantine Books           3783
# Bantam Books               3646
#                            ...
# Hannover House                1
# Amber Quill Press, LLC.       1
# Lunchbox Press                1
# Ugly Town                     1
# Connaught                     1
# Name: Publisher, Length: 16807, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Image-URL-S in books dataset
# ['http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.THUMBZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.THUMBZZZ.jpg']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Image-URL-S in books dataset
# http://images.amazon.com/images/P/185326119X.01.THUMBZZZ.jpg    2
# http://images.amazon.com/images/P/006099486X.01.THUMBZZZ.jpg    2
# http://images.amazon.com/images/P/044991089X.01.THUMBZZZ.jpg    2
# http://images.amazon.com/images/P/086611873X.01.THUMBZZZ.jpg    2
# http://images.amazon.com/images/P/039552105X.01.THUMBZZZ.jpg    2
#                                                                ..
# http://images.amazon.com/images/P/1860461050.01.THUMBZZZ.jpg    1
# http://images.amazon.com/images/P/0553213067.01.THUMBZZZ.jpg    1
# http://images.amazon.com/images/P/156971634X.01.THUMBZZZ.jpg    1
# http://images.amazon.com/images/P/349223674X.01.THUMBZZZ.jpg    1
# http://images.amazon.com/images/P/0767409752.01.THUMBZZZ.jpg    1
# Name: Image-URL-S, Length: 271044, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Image-URL-M in books dataset
# ['http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.MZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.MZZZZZZZ.jpg']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Image-URL-M in books dataset
# http://images.amazon.com/images/P/185326119X.01.MZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/006099486X.01.MZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/044991089X.01.MZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/086611873X.01.MZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/039552105X.01.MZZZZZZZ.jpg    2
#                                                                ..
# http://images.amazon.com/images/P/1860461050.01.MZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/0553213067.01.MZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/156971634X.01.MZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/349223674X.01.MZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/0767409752.01.MZZZZZZZ.jpg    1
# Name: Image-URL-M, Length: 271044, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________
# Unique values in Image-URL-L in books dataset
# ['http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg' ...
#  'http://images.amazon.com/images/P/006008667X.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0192126040.01.LZZZZZZZ.jpg'
#  'http://images.amazon.com/images/P/0767409752.01.LZZZZZZZ.jpg']
# ______________________________________________________________________________________________________________________________________________________
# Unique value count in Image-URL-L in books dataset
# http://images.amazon.com/images/P/225307649X.01.LZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/044021145X.01.LZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/044991089X.01.LZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/039552105X.01.LZZZZZZZ.jpg    2
# http://images.amazon.com/images/P/014062063X.01.LZZZZZZZ.jpg    2
#                                                                ..
# http://images.amazon.com/images/P/1860461050.01.LZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/0553213067.01.LZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/156971634X.01.LZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/349223674X.01.LZZZZZZZ.jpg    1
# http://images.amazon.com/images/P/0767409752.01.LZZZZZZZ.jpg    1
# Name: Image-URL-L, Length: 271041, dtype: int64
# ______________________________________________________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# For book dataset:
#
#  **Year of publication**: It contains values as 'DK Publishing Inc' and 'Gallimard' which seems to be incorrect therefore it is required to keep an eye on it.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df1[df1['Year-Of-Publication']== 'DK Publishing Inc']
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %%
# Write your code to make your dataset analysis ready.
df1['Book-Title'][df1['Year-Of-Publication']== 'DK Publishing Inc']
# Out:
# 209538    DK Readers: Creating the X-Men, How It All Beg...
# 221678    DK Readers: Creating the X-Men, How Comic Book...
# Name: Book-Title, dtype: object

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %%
df1.at[209538 ,'Publisher'] = 'DK Publishing Inc'
df1.at[209538 ,'Year-Of-Publication'] = '2000'
df1.at[209538 ,'Book-Title'] = 'DK Readers: Creating the X-Men, How It All Began (Level 4: Proficient Readers)'
df1.at[209538 ,'Book-Author'] = 'Michael Teitelbaum'
df1.at[221678 ,'Publisher'] = 'DK Publishing Inc'
df1.at[221678 ,'Year-Of-Publication'] = '2000'
df1.at[221687 ,'Book-Title'] = 'DK Readers: Creating the X-Men, How Comic Books Come to Life (Level 4: Proficient Readers)'
df1.at[221678 ,'Book-Author'] = 'James Buckley'

# %%
#have a look at index 209538
df1.loc[209538]
# Out:
# ISBN                                                          078946697X
# Book-Title             DK Readers: Creating the X-Men, How It All Beg...
# Book-Author                                           Michael Teitelbaum
# Year-Of-Publication                                                 2000
# Publisher                                              DK Publishing Inc
# Image-URL-S            http://images.amazon.com/images/P/078946697X.0...
# Image-URL-M            http://images.amazon.com/images/P/078946697X.0...
# Image-URL-L                                                          NaN
# Name: 209538, dtype: object

# %%
#have a look at index 221678
df1.loc[221678]
# Out:
# ISBN                                                          0789466953
# Book-Title             DK Readers: Creating the X-Men, How Comic Book...
# Book-Author                                                James Buckley
# Year-Of-Publication                                                 2000
# Publisher                                              DK Publishing Inc
# Image-URL-S            http://images.amazon.com/images/P/0789466953.0...
# Image-URL-M            http://images.amazon.com/images/P/0789466953.0...
# Image-URL-L                                                          NaN
# Name: 221678, dtype: object

# %%
# Lets check in hiw many rows are the year of publicatiobn as gallimard
df1[df1['Year-Of-Publication']=='Gallimard']
# Out:
#               ISBN                                         Book-Title  \
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
#
#        Book-Author Year-Of-Publication  \
# 220731        2003           Gallimard
#
#                                                 Publisher  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                               Image-URL-S  \
# 220731  http://images.amazon.com/images/P/2070426769.0...
#
#                                               Image-URL-M Image-URL-L
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN

# %%
# Write your code to make your dataset analysis ready.
df1['Book-Title'][df1['Year-Of-Publication']== 'Gallimard']
# Out:
# 220731    Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# Name: Book-Title, dtype: object

# %%
# lets coorect the values at index 220731
df1.at[220731,'Book-Author']='Jean-Marie Gustave Le'
df1.at[220731,'Book-Title']='Peuple du cel,suivi de les Bergers'
df1.at[220731,'Publisher']='Gallimard'
df1.at[220731,'Year-Of-Publication']='2003'

# %%
df1.loc[220731]
# Out:
# ISBN                                                          2070426769
# Book-Title                            Peuple du cel,suivi de les Bergers
# Book-Author                                        Jean-Marie Gustave Le
# Year-Of-Publication                                                 2003
# Publisher                                                      Gallimard
# Image-URL-S            http://images.amazon.com/images/P/2070426769.0...
# Image-URL-M            http://images.amazon.com/images/P/2070426769.0...
# Image-URL-L                                                          NaN
# Name: 220731, dtype: object

# %% [markdown]
# Answer Here.

# %%
#since we are living in 2023 so we have to remove values in which the year of publication is greater than 2022.
# Converting year of publication in Numbers
df1['Year-Of-Publication'] = df1['Year-Of-Publication'].astype(int)
df1['Year-Of-Publication'].sort_values(ascending=False).unique()
# Out:
# array([2050, 2038, 2037, 2030, 2026, 2024, 2021, 2020, 2012, 2011, 2010,
#        2008, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987, 1986,
#        1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975,
#        1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943, 1942,
#        1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931,
#        1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920,
#        1919, 1917, 1914, 1911, 1910, 1909, 1908, 1906, 1904, 1902, 1901,
#        1900, 1897, 1806, 1378, 1376,    0])

# %%
df1[df1['Year-Of-Publication']>=2023]
# Out:
#               ISBN                                         Book-Title  \
# 37487   0671746103  MY TEACHER FRIED MY BRAINS (RACK SIZE) (MY TEA...
# 55676   0671791990  MY TEACHER FLUNKED THE PLANET (RACK SIZE) (MY ...
# 78168   0870449842                                   Crossing America
# 80264   0140301690  Alice's Adventures in Wonderland and Through t...
# 97826   0140201092      Outline of European Architecture (Pelican S.)
# 116053  0394701658                       Three Plays of Eugene Oneill
# 118294  3442436893        Das groÃ?Â?e BÃ?Â¶se- MÃ?Â¤dchen- Lesebuch.
# 192993  0870446924  Field Guide to the Birds of North America, 3rd...
# 228173  0671266500       FOREST PEOPLE (Touchstone Books (Hardcover))
# 240169  0684718022            In Our Time: Stories (Scribner Classic)
# 246842  0380000059                                              CLOUT
# 255409  068471809X                               To Have and Have Not
# 260974  0671740989        FOOTBALL SUPER TEAMS : FOOTBALL SUPER TEAMS
#
#                         Book-Author  Year-Of-Publication  \
# 37487                       Coville                 2030
# 55676                 Bruce Coville                 2030
# 78168   National Geographic Society                 2030
# 80264                 Lewis Carroll                 2050
# 97826              Nikolaus Pevsner                 2050
# 116053               Eugene O'Neill                 2038
# 118294                  Kathy Lette                 2026
# 192993  National Geographic Society                 2030
# 228173            Colin M. Turnbull                 2030
# 240169             Ernest Hemingway                 2030
# 246842                   D. GIBBONS                 2024
# 255409             Ernest Hemingway                 2037
# 260974                  Bill Gutman                 2030
#
#                                          Publisher  \
# 37487                                      Aladdin
# 55676                                      Aladdin
# 78168                          National Geographic
# 80264                                 Puffin Books
# 97826                                  Penguin USA
# 116053                           Vintage Books USA
# 118294                                    Goldmann
# 192993                         National Geographic
# 228173                        Simon &amp; Schuster
# 240169                               Collier Books
# 246842                                        Avon
# 255409                        Simon &amp; Schuster
# 260974  Simon &amp; Schuster Children's Publishing
#
#                                               Image-URL-S  \
# 37487   http://images.amazon.com/images/P/0671746103.0...
# 55676   http://images.amazon.com/images/P/0671791990.0...
# 78168   http://images.amazon.com/images/P/0870449842.0...
# 80264   http://images.amazon.com/images/P/0140301690.0...
# 97826   http://images.amazon.com/images/P/0140201092.0...
# 116053  http://images.amazon.com/images/P/0394701658.0...
# 118294  http://images.amazon.com/images/P/3442436893.0...
# 192993  http://images.amazon.com/images/P/0870446924.0...
# 228173  http://images.amazon.com/images/P/0671266500.0...
# 240169  http://images.amazon.com/images/P/0684718022.0...
# 246842  http://images.amazon.com/images/P/0380000059.0...
# 255409  http://images.amazon.com/images/P/068471809X.0...
# 260974  http://images.amazon.com/images/P/0671740989.0...
#
#                                               Image-URL-M  \
# 37487   http://images.amazon.com/images/P/0671746103.0...
# 55676   http://images.amazon.com/images/P/0671791990.0...
# 78168   http://images.amazon.com/images/P/0870449842.0...
# 80264   http://images.amazon.com/images/P/0140301690.0...
# 97826   http://images.amazon.com/images/P/0140201092.0...
# 116053  http://images.amazon.com/images/P/0394701658.0...
# 118294  http://images.amazon.com/images/P/3442436893.0...
# 192993  http://images.amazon.com/images/P/0870446924.0...
# 228173  http://images.amazon.com/images/P/0671266500.0...
# 240169  http://images.amazon.com/images/P/0684718022.0...
# 246842  http://images.amazon.com/images/P/0380000059.0...
# 255409  http://images.amazon.com/images/P/068471809X.0...
# 260974  http://images.amazon.com/images/P/0671740989.0...
#
#                                               Image-URL-L
# 37487   http://images.amazon.com/images/P/0671746103.0...
# 55676   http://images.amazon.com/images/P/0671791990.0...
# 78168   http://images.amazon.com/images/P/0870449842.0...
# 80264   http://images.amazon.com/images/P/0140301690.0...
# 97826   http://images.amazon.com/images/P/0140201092.0...
# 116053  http://images.amazon.com/images/P/0394701658.0...
# 118294  http://images.amazon.com/images/P/3442436893.0...
# 192993  http://images.amazon.com/images/P/0870446924.0...
# 228173  http://images.amazon.com/images/P/0671266500.0...
# 240169  http://images.amazon.com/images/P/0684718022.0...
# 246842  http://images.amazon.com/images/P/0380000059.0...
# 255409  http://images.amazon.com/images/P/068471809X.0...
# 260974  http://images.amazon.com/images/P/0671740989.0...

# %%
# lets see the Year of publication which is 0
df1.loc[df1['Year-Of-Publication']==0]
# Out:
#               ISBN                                         Book-Title  \
# 176     3150000335                                   Kabale Und Liebe
# 188     342311360X                            Die Liebe in Den Zelten
# 288     0571197639                        Poisonwood Bible Edition Uk
# 351     3596214629       Herr Der Fliegen (Fiction, Poetry and Drama)
# 542     8845229041  Biblioteca Universale Rizzoli: Sulla Sponda De...
# ...            ...                                                ...
# 270794  014029953X                         Foe (Essential.penguin S.)
# 270913  0340571187                                     Postmens House
# 271094  8427201079                           El Misterio De Sittaford
# 271182  0887781721                                          Tom Penny
# 271196  3150013763                                     Der Hofmeister
#
#                    Book-Author  Year-Of-Publication  \
# 176                   Schiller                    0
# 188     Gabriel Garcia Marquez                    0
# 288         Barbara Kingsolver                    0
# 351                    Golding                    0
# 542                   P Coelho                    0
# ...                        ...                  ...
# 270794            J.M. Coetzee                    0
# 270913        Maggie Hemingway                    0
# 271094         Agatha Christie                    0
# 271182             Tony German                    0
# 271196              Jakob Lenz                    0
#
#                                  Publisher  \
# 176        Philipp Reclam, Jun Verlag GmbH
# 188     Deutscher Taschenbuch Verlag (DTV)
# 288                        Faber Faber Inc
# 351        Fischer Taschenbuch Verlag GmbH
# 542                     Fabbri - RCS Libri
# ...                                    ...
# 270794                   Penguin Books Ltd
# 270913                    Trafalgar Square
# 271094                    Editorial Molino
# 271182                P. Martin Associates
# 271196     Philipp Reclam, Jun Verlag GmbH
#
#                                               Image-URL-S  \
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
#                                               Image-URL-M  \
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
#                                               Image-URL-L
# 176     http://images.amazon.com/images/P/3150000335.0...
# 188     http://images.amazon.com/images/P/342311360X.0...
# 288     http://images.amazon.com/images/P/0571197639.0...
# 351     http://images.amazon.com/images/P/3596214629.0...
# 542     http://images.amazon.com/images/P/8845229041.0...
# ...                                                   ...
# 270794  http://images.amazon.com/images/P/014029953X.0...
# 270913  http://images.amazon.com/images/P/0340571187.0...
# 271094  http://images.amazon.com/images/P/8427201079.0...
# 271182  http://images.amazon.com/images/P/0887781721.0...
# 271196  http://images.amazon.com/images/P/3150013763.0...
#
# [4618 rows x 8 columns]

# %%
#Replacing incorrect publication year by mode i.e 2002
df1.loc[df1['Year-Of-Publication']>=2023,'Year-Of-Publication']=2002
df1.loc[df1['Year-Of-Publication']==0,'Year-Of-Publication']=2002

# %%
#Checking for null values
df1.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
df1[df1['Book-Author'].isnull()]
# Out:
#               ISBN                                         Book-Title  \
# 187689  9627982032  The Credit Suisse Guide to Managing Your Perso...
#
#        Book-Author  Year-Of-Publication                       Publisher  \
# 187689         NaN                 1995  Edinburgh Financial Publishing
#
#                                               Image-URL-S  \
# 187689  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-M  \
# 187689  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-L
# 187689  http://images.amazon.com/images/P/9627982032.0...

# %%
df1['Book-Author'].value_counts()
# Out:
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# R. Gelman                 1
# Ellery R. Sheets          1
# Artiste C. Arthur         1
# Emily Pearl Kingsley      1
# Christopher  Biffle       1
# Name: Book-Author, Length: 102022, dtype: int64

# %%
#records containg Downes in author name
mask=df1['Book-Author'].str.contains('Downes',case=False,na=False)

# %%
df1[mask]
# Out:
#               ISBN                                         Book-Title  \
# 9300    0789426323  The Starlight Princess and Other Princess Stories
# 41756   087584801X  Unleashing the Killer App: Digital Strategies ...
# 104999  0812025229  Dictionary of finance and investment terms (Ba...
# 166910  1578512611  Unleashing the Killer App: Digital Strategies ...
# 215606  078684440X                                     102 Dalmatians
# 217668  0553218425                                  Evenings in Paris
# 222654  0066211298  The Strategy Machine: Building Your Business O...
# 242588  0071396683  Teach Yourself 101 Key Ideas Literature (Teach...
# 261979  0802705405    The New York Philharmonic Guide to the Symphony
# 270443  1898941750                          The Devil Drives a Jaguar
#
#             Book-Author  Year-Of-Publication                      Publisher  \
# 9300     Belinda Downes                 1999                         DK Ink
# 41756      Larry Downes                 1998  Harvard Business School Press
# 104999      John Downes                 1985                       Barron's
# 166910     Larry Downes                 2000  Harvard Business School Press
# 215606     Alice Downes                 2000                      Disney Pr
# 217668  Kathleen Downes                 1987                      Loveswept
# 222654     Larry Downes                 2002                 HarperBusiness
# 242588   Brenda  Downes                 2002                    McGraw-Hill
# 261979    Edward Downes                 1976           Walker &amp; Company
# 270443   Suzanne Downes                 2002                  Country Books
#
#                                               Image-URL-S  \
# 9300    http://images.amazon.com/images/P/0789426323.0...
# 41756   http://images.amazon.com/images/P/087584801X.0...
# 104999  http://images.amazon.com/images/P/0812025229.0...
# 166910  http://images.amazon.com/images/P/1578512611.0...
# 215606  http://images.amazon.com/images/P/078684440X.0...
# 217668  http://images.amazon.com/images/P/0553218425.0...
# 222654  http://images.amazon.com/images/P/0066211298.0...
# 242588  http://images.amazon.com/images/P/0071396683.0...
# 261979  http://images.amazon.com/images/P/0802705405.0...
# 270443  http://images.amazon.com/images/P/1898941750.0...
#
#                                               Image-URL-M  \
# 9300    http://images.amazon.com/images/P/0789426323.0...
# 41756   http://images.amazon.com/images/P/087584801X.0...
# 104999  http://images.amazon.com/images/P/0812025229.0...
# 166910  http://images.amazon.com/images/P/1578512611.0...
# 215606  http://images.amazon.com/images/P/078684440X.0...
# 217668  http://images.amazon.com/images/P/0553218425.0...
# 222654  http://images.amazon.com/images/P/0066211298.0...
# 242588  http://images.amazon.com/images/P/0071396683.0...
# 261979  http://images.amazon.com/images/P/0802705405.0...
# 270443  http://images.amazon.com/images/P/1898941750.0...
#
#                                               Image-URL-L
# 9300    http://images.amazon.com/images/P/0789426323.0...
# 41756   http://images.amazon.com/images/P/087584801X.0...
# 104999  http://images.amazon.com/images/P/0812025229.0...
# 166910  http://images.amazon.com/images/P/1578512611.0...
# 215606  http://images.amazon.com/images/P/078684440X.0...
# 217668  http://images.amazon.com/images/P/0553218425.0...
# 222654  http://images.amazon.com/images/P/0066211298.0...
# 242588  http://images.amazon.com/images/P/0071396683.0...
# 261979  http://images.amazon.com/images/P/0802705405.0...
# 270443  http://images.amazon.com/images/P/1898941750.0...

# %% [markdown]
# None of the record contains Downes Larissa Anne as a author name

# %%
df1.at[187689,'Book-Author']='Downes Larissa Anne'

# %%
df1.loc[187689]
# Out:
# ISBN                                                          9627982032
# Book-Title             The Credit Suisse Guide to Managing Your Perso...
# Book-Author                                          Downes Larissa Anne
# Year-Of-Publication                                                 1995
# Publisher                                 Edinburgh Financial Publishing
# Image-URL-S            http://images.amazon.com/images/P/9627982032.0...
# Image-URL-M            http://images.amazon.com/images/P/9627982032.0...
# Image-URL-L            http://images.amazon.com/images/P/9627982032.0...
# Name: 187689, dtype: object

# %%
# checking null values in Publisher column
df1.loc[df1['Publisher'].isnull()]
# Out:
#               ISBN       Book-Title      Book-Author  Year-Of-Publication  \
# 128890  193169656X      Tyrant Moon  Elaine Corvidae                 2002
# 129037  1931696993  Finders Keepers  Linnea Sinclair                 2001
#
#        Publisher                                        Image-URL-S  \
# 128890       NaN  http://images.amazon.com/images/P/193169656X.0...
# 129037       NaN  http://images.amazon.com/images/P/1931696993.0...
#
#                                               Image-URL-M  \
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 129037  http://images.amazon.com/images/P/1931696993.0...
#
#                                               Image-URL-L
# 128890  http://images.amazon.com/images/P/193169656X.0...
# 129037  http://images.amazon.com/images/P/1931696993.0...

# %%
mask=df1['Publisher'].str.contains('Novelbooks',case=False,na=False)

# %%
df1[mask]
# Out:
#               ISBN                                   Book-Title  \
# 126169  1591051827                           The Guarder Factor
# 126707  1591051894                         Sorrows of Adoration
# 126708  1591051401                            Angels on Crusade
# 126762  1931696934                             Winter's Orphans
# 127002  1591051363                   Beyond Those Distant Stars
# 127005  159105236X                             The Starry Child
# 127279  1591051266                             The Best Defense
# 127548  1591051428                           Dangerous Medicine
# 128078  1931696861       The Binding (Sylvan Wars Saga, Book 1)
# 128079  1931696772  The Choosing (The Sylvan Wars Saga, Book 2)
# 128676  1931696624                            Dayspring Dawning
# 128784  1931696608                        A Woman of Experience
# 128888  1591050480                             Beloved Stranger
# 128936  1591050316                        Apology for the Devil
# 128995  193169673X                                 Guarder Lore
# 129000  193169687X                              Escape The Past
# 129039  1931696853                            The Dragon's Horn
# 144543  193169690X                     The Anonymous Amanuensis
# 149212  1591050367             An American Redneck in Hong Kong
# 164402  1931696721                           The Scent of Stone
# 178217  1591050901                                    Greenwood
# 195496  1931696942                                         Fate
# 207130  1591050820                        Saratoga Summer, 1863
# 207132  1931696837                                     Unlawful
# 212941  1591050804                                  Winter Fire
# 234548  1931696810                                Mating Season
# 236154  1591050359                JUR: A STORY OF PREDAWN EARTH
#
#                 Book-Author  Year-Of-Publication         Publisher  \
# 126169     Shawn P. Madison                 2003  NovelBooks, Inc.
# 126707     Kimberly Chapman                 2003  NovelBooks, Inc.
# 126708     Jennifer Macaire                 2003   NovelBooks, Inc
# 126762      Elaine Corvidae                 2001        Novelbooks
# 127002     John B. Rosenman                 2003        Novelbooks
# 127005           Lynn Hanna                 2003        Novelbooks
# 127279           Todd Stone                 2003        Novelbooks
# 127548          Jane Toombs                 2003        Novelbooks
# 128078     PhyllisAnn Welsh                 2001        Novelbooks
# 128079    Phyllis Ann Welsh                 2002        Novelbooks
# 128676        Jeanine Berry                 2002        Novelbooks
# 128784          Kay Gregory                 2002        Novelbooks
# 128888    Patricia Crossley                 2002        Novelbooks
# 128936       Stewart Thomas                 2002        Novelbooks
# 128995     Shawn P. Madison                 2002        Novelbooks
# 129000         K. G. McAbee                 2001        Novelbooks
# 129039      Glynnis Kincaid                 2001        Novelbooks
# 144543       Judith B. Glad                 2001  NovelBooks, Inc.
# 149212                  x x                 2002  NovelBooks, Inc.
# 164402    Savannah Michaels                 2002  NovelBooks, Inc.
# 178217           Sue Wilson                 2003  NovelBooks, Inc.
# 195496  Robert Arthur Smith                 2001  NovelBooks, Inc.
# 207130        Dorice Nelson                 2002  NovelBooks, Inc.
# 207132                  x x                 2002  NovelBooks, Inc.
# 212941                  x x                 2002  NovelBooks, Inc.
# 234548                  x x                 2002  NovelBooks, Inc.
# 236154          Tom Johnson                 2002  NovelBooks, Inc.
#
#                                               Image-URL-S  \
# 126169  http://images.amazon.com/images/P/1591051827.0...
# 126707  http://images.amazon.com/images/P/1591051894.0...
# 126708  http://images.amazon.com/images/P/1591051401.0...
# 126762  http://images.amazon.com/images/P/1931696934.0...
# 127002  http://images.amazon.com/images/P/1591051363.0...
# 127005  http://images.amazon.com/images/P/159105236X.0...
# 127279  http://images.amazon.com/images/P/1591051266.0...
# 127548  http://images.amazon.com/images/P/1591051428.0...
# 128078  http://images.amazon.com/images/P/1931696861.0...
# 128079  http://images.amazon.com/images/P/1931696772.0...
# 128676  http://images.amazon.com/images/P/1931696624.0...
# 128784  http://images.amazon.com/images/P/1931696608.0...
# 128888  http://images.amazon.com/images/P/1591050480.0...
# 128936  http://images.amazon.com/images/P/1591050316.0...
# 128995  http://images.amazon.com/images/P/193169673X.0...
# 129000  http://images.amazon.com/images/P/193169687X.0...
# 129039  http://images.amazon.com/images/P/1931696853.0...
# 144543  http://images.amazon.com/images/P/193169690X.0...
# 149212  http://images.amazon.com/images/P/1591050367.0...
# 164402  http://images.amazon.com/images/P/1931696721.0...
# 178217  http://images.amazon.com/images/P/1591050901.0...
# 195496  http://images.amazon.com/images/P/1931696942.0...
# 207130  http://images.amazon.com/images/P/1591050820.0...
# 207132  http://images.amazon.com/images/P/1931696837.0...
# 212941  http://images.amazon.com/images/P/1591050804.0...
# 234548  http://images.amazon.com/images/P/1931696810.0...
# 236154  http://images.amazon.com/images/P/1591050359.0...
#
#                                               Image-URL-M  \
# 126169  http://images.amazon.com/images/P/1591051827.0...
# 126707  http://images.amazon.com/images/P/1591051894.0...
# 126708  http://images.amazon.com/images/P/1591051401.0...
# 126762  http://images.amazon.com/images/P/1931696934.0...
# 127002  http://images.amazon.com/images/P/1591051363.0...
# 127005  http://images.amazon.com/images/P/159105236X.0...
# 127279  http://images.amazon.com/images/P/1591051266.0...
# 127548  http://images.amazon.com/images/P/1591051428.0...
# 128078  http://images.amazon.com/images/P/1931696861.0...
# 128079  http://images.amazon.com/images/P/1931696772.0...
# 128676  http://images.amazon.com/images/P/1931696624.0...
# 128784  http://images.amazon.com/images/P/1931696608.0...
# 128888  http://images.amazon.com/images/P/1591050480.0...
# 128936  http://images.amazon.com/images/P/1591050316.0...
# 128995  http://images.amazon.com/images/P/193169673X.0...
# 129000  http://images.amazon.com/images/P/193169687X.0...
# 129039  http://images.amazon.com/images/P/1931696853.0...
# 144543  http://images.amazon.com/images/P/193169690X.0...
# 149212  http://images.amazon.com/images/P/1591050367.0...
# 164402  http://images.amazon.com/images/P/1931696721.0...
# 178217  http://images.amazon.com/images/P/1591050901.0...
# 195496  http://images.amazon.com/images/P/1931696942.0...
# 207130  http://images.amazon.com/images/P/1591050820.0...
# 207132  http://images.amazon.com/images/P/1931696837.0...
# 212941  http://images.amazon.com/images/P/1591050804.0...
# 234548  http://images.amazon.com/images/P/1931696810.0...
# 236154  http://images.amazon.com/images/P/1591050359.0...
#
#                                               Image-URL-L
# 126169  http://images.amazon.com/images/P/1591051827.0...
# 126707  http://images.amazon.com/images/P/1591051894.0...
# 126708  http://images.amazon.com/images/P/1591051401.0...
# 126762  http://images.amazon.com/images/P/1931696934.0...
# 127002  http://images.amazon.com/images/P/1591051363.0...
# 127005  http://images.amazon.com/images/P/159105236X.0...
# 127279  http://images.amazon.com/images/P/1591051266.0...
# 127548  http://images.amazon.com/images/P/1591051428.0...
# 128078  http://images.amazon.com/images/P/1931696861.0...
# 128079  http://images.amazon.com/images/P/1931696772.0...
# 128676  http://images.amazon.com/images/P/1931696624.0...
# 128784  http://images.amazon.com/images/P/1931696608.0...
# 128888  http://images.amazon.com/images/P/1591050480.0...
# 128936  http://images.amazon.com/images/P/1591050316.0...
# 128995  http://images.amazon.com/images/P/193169673X.0...
# 129000  http://images.amazon.com/images/P/193169687X.0...
# 129039  http://images.amazon.com/images/P/1931696853.0...
# 144543  http://images.amazon.com/images/P/193169690X.0...
# 149212  http://images.amazon.com/images/P/1591050367.0...
# 164402  http://images.amazon.com/images/P/1931696721.0...
# 178217  http://images.amazon.com/images/P/1591050901.0...
# 195496  http://images.amazon.com/images/P/1931696942.0...
# 207130  http://images.amazon.com/images/P/1591050820.0...
# 207132  http://images.amazon.com/images/P/1931696837.0...
# 212941  http://images.amazon.com/images/P/1591050804.0...
# 234548  http://images.amazon.com/images/P/1931696810.0...
# 236154  http://images.amazon.com/images/P/1591050359.0...

# %%
mask=df1['Publisher'].str.contains('Simon',case=False,na=False)

# %%
df1[mask]
# Out:
#               ISBN                                         Book-Title  \
# 84      0743403843                                           Decipher
# 170     0671504282  LAW OF THE JUNGLE (HARDY BOYS CASE FILE 105) :...
# 292     0684833395                                           Catch 22
# 494     0020199090                            Joshua In the Holy Land
# 505     0684854953  Santa Pete : A Novel Of Christmas Present And ...
# ...            ...                                                ...
# 271029  0671516760                                           My Story
# 271202  0689869991             Sunlight and Shadow (Once Upon a Time)
# 271258  0684857502                               TEXASVILLE : A Novel
# 271312  0671015885               Star Trek: First Contact (Star Trek)
# 271345  0684860112        Driving to Detroit: Memoirs of a Fast Woman
#
#                   Book-Author  Year-Of-Publication  \
# 84                Stel Pavlou                 2002
# 170         Franklin W. Dixon                 1995
# 292             Joseph Heller                 1996
# 494            Joseph Girzone                 1993
# 505         Christopher Moore                 1998
# ...                       ...                  ...
# 271029  Sarah Duchess of York                 1997
# 271202          Cameron Dokey                 2004
# 271258         Larry McMurtry                 1999
# 271312           J.M. Dillard                 1997
# 271345        Lesley Hazleton                 1999
#
#                                     Publisher  \
# 84      Simon &amp; Schuster (Trade Division)
# 170                               Simon Pulse
# 292                      Simon &amp; Schuster
# 494                      Simon Schuster Trade
# 505                      Simon &amp; Schuster
# ...                                       ...
# 271029  Simon &amp; Schuster (Trade Division)
# 271202                            Simon Pulse
# 271258                   Simon &amp; Schuster
# 271312  Simon &amp; Schuster (Trade Division)
# 271345  Simon &amp; Schuster (Trade Division)
#
#                                               Image-URL-S  \
# 84      http://images.amazon.com/images/P/0743403843.0...
# 170     http://images.amazon.com/images/P/0671504282.0...
# 292     http://images.amazon.com/images/P/0684833395.0...
# 494     http://images.amazon.com/images/P/0020199090.0...
# 505     http://images.amazon.com/images/P/0684854953.0...
# ...                                                   ...
# 271029  http://images.amazon.com/images/P/0671516760.0...
# 271202  http://images.amazon.com/images/P/0689869991.0...
# 271258  http://images.amazon.com/images/P/0684857502.0...
# 271312  http://images.amazon.com/images/P/0671015885.0...
# 271345  http://images.amazon.com/images/P/0684860112.0...
#
#                                               Image-URL-M  \
# 84      http://images.amazon.com/images/P/0743403843.0...
# 170     http://images.amazon.com/images/P/0671504282.0...
# 292     http://images.amazon.com/images/P/0684833395.0...
# 494     http://images.amazon.com/images/P/0020199090.0...
# 505     http://images.amazon.com/images/P/0684854953.0...
# ...                                                   ...
# 271029  http://images.amazon.com/images/P/0671516760.0...
# 271202  http://images.amazon.com/images/P/0689869991.0...
# 271258  http://images.amazon.com/images/P/0684857502.0...
# 271312  http://images.amazon.com/images/P/0671015885.0...
# 271345  http://images.amazon.com/images/P/0684860112.0...
#
#                                               Image-URL-L
# 84      http://images.amazon.com/images/P/0743403843.0...
# 170     http://images.amazon.com/images/P/0671504282.0...
# 292     http://images.amazon.com/images/P/0684833395.0...
# 494     http://images.amazon.com/images/P/0020199090.0...
# 505     http://images.amazon.com/images/P/0684854953.0...
# ...                                                   ...
# 271029  http://images.amazon.com/images/P/0671516760.0...
# 271202  http://images.amazon.com/images/P/0689869991.0...
# 271258  http://images.amazon.com/images/P/0684857502.0...
# 271312  http://images.amazon.com/images/P/0671015885.0...
# 271345  http://images.amazon.com/images/P/0684860112.0...
#
# [5428 rows x 8 columns]

# %%
 df1.at[128890,'Publisher']='NovelBooks, Inc.'
 df1.at[129037,'Publisher']='Simon &amp; Schuster'

# %%
# checking null value in Image-URL-L column
df1.loc[df1['Image-URL-L'].isnull()]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769                 Peuple du cel,suivi de les Bergers
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#                   Book-Author  Year-Of-Publication          Publisher  \
# 209538     Michael Teitelbaum                 2000  DK Publishing Inc
# 220731  Jean-Marie Gustave Le                 2003          Gallimard
# 221678          James Buckley                 2000  DK Publishing Inc
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %%
df1.at[209538,'Image-URL-L']='https://m.media-amazon.com/images/I/51HR6W22SFL._SX312_BO1,204,203,200_.jpg'
df1.at[220731,'Image-URL-L']='https://books.google.co.in/books/content?id=O-SrPQAACAAJ&printsec=frontcover&img=1&zoom=1&imgtk=AFLRE70uA-IF8I7lU89Ksou-kxhY4ZKzeHbbaRTqLfl8f05OWc0pRS3Ct43gYUhz_xEu6ThzaVcAHe2NXwmFs3xuYTzg4G5JiXhvuLkmWv_N2QjppZ2hPUmDR7FMrUufn2bHxH364UFR'
df1.at[221678,'Image-URL-L']='https://m.media-amazon.com/images/I/51Z5YNCMB8L.jpg'

# %%
# Lets check is there any Duplicate values
df1.duplicated().any()
# Out:
# False

# %%
# lets check is there any null values
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271360 non-null  object
#  3   Year-Of-Publication  271360 non-null  int64
#  4   Publisher            271360 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271360 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 16.6+ MB

# %% [markdown]
# Now Its time for Users Data set

# %%
#checking unique values of different features of the user dataset
df3.apply(lambda x: len(x.unique()))
# Out:
# User-ID     278858
# Location     57339
# Age            166
# dtype: int64

# %%
df3.rename(columns={'User-ID':'user_id'},inplace=True)

# %%
df3.Age.unique()
# Out:
# array([ nan,  18.,  17.,  61.,  26.,  14.,  25.,  19.,  46.,  55.,  32.,
#         24.,  20.,  34.,  23.,  51.,  31.,  21.,  44.,  30.,  57.,  43.,
#         37.,  41.,  54.,  42.,  50.,  39.,  53.,  47.,  36.,  28.,  35.,
#         13.,  58.,  49.,  38.,  45.,  62.,  63.,  27.,  33.,  29.,  66.,
#         40.,  15.,  60.,   0.,  79.,  22.,  16.,  65.,  59.,  48.,  72.,
#         56.,  67.,   1.,  80.,  52.,  69.,  71.,  73.,  78.,   9.,  64.,
#        103., 104.,  12.,  74.,  75., 231.,   3.,  76.,  83.,  68., 119.,
#         11.,  77.,   2.,  70.,  93.,   8.,   7.,   4.,  81., 114., 230.,
#        239.,  10.,   5., 148., 151.,   6., 101., 201.,  96.,  84.,  82.,
#         90., 123., 244., 133.,  91., 128.,  94.,  85., 141., 110.,  97.,
#        219.,  86., 124.,  92., 175., 172., 209., 212., 237.,  87., 162.,
#        100., 156., 136.,  95.,  89., 106.,  99., 108., 210.,  88., 199.,
#        147., 168., 132., 159., 186., 152., 102., 116., 200., 115., 226.,
#        137., 207., 229., 138., 109., 105., 228., 183., 204.,  98., 223.,
#        113., 208., 107., 157., 111., 146., 118., 220., 143., 140., 189.,
#        127.])

# %% [markdown]
# There is nan values and some values are there which could not be there in dataset such as age greater than 90 and less than 6 because peoples greater than 90 and less 6 years of age do not read books.So we have to remove these values.

# %%
# lets check how many values are less than or equal to 6 years and greater than 90
df3[(df3['Age']<6) | (df3['Age']>90)]
# Out:
#         User-ID                                       Location    Age  \
# 219         220                       bogota, bogota, colombia    0.0
# 469         470                     indianapolis, indiana, usa    0.0
# 561         562  adfdaf, australian capital territory, albania    0.0
# 612         613                            ankara, n/a, turkey    1.0
# 670         671                   jeddah, jeddah, saudi arabia    1.0
# ...         ...                                            ...    ...
# 277107   277108                    quinto, ticino, switzerland  104.0
# 277503   277504                     san diego, california, usa  103.0
# 277558   277559                     lake george, new york, usa   98.0
# 277908   277909                          phoenix, arizona, usa    2.0
# 278301   278302       düsseldorf, nordrhein-westfalen, germany  104.0
#
#             Country
# 219        colombia
# 469             usa
# 561         albania
# 612          turkey
# 670          arabia
# ...             ...
# 277107  switzerland
# 277503          usa
# 277558          usa
# 277908          usa
# 278301      germany
#
# [1338 rows x 4 columns]

# %% [markdown]
# Hence there are 1338 such records

# %%
# lets create a variable for required age group
required = df3[(df3['Age'] <= 90) | (df3['Age'] >=6)]

# %%
# lets check the mean age
mean = round(required['Age'].mean())   
mean
# Out:
# 35

# %%
# lets find unique values in location column
df3.Location.unique()
# Out:
# array(['nyc, new york, usa', 'stockton, california, usa',
#        'moscow, yukon territory, russia', ...,
#        'sergnano, lombardia, italy', 'stranraer, n/a, united kingdom',
#        'tacoma, washington, united kingdom'], dtype=object)

# %%
# lets find out total unique values in location column
df3.Location.nunique()
# Out:
# 57339

# %%
def country(string):
  '''
  It returns the country from the location of the user
  '''
  country = string.rpartition(' ')[-1]
  if country=='zealand':
    return 'new zealand'
  elif country=='kingdom':
    return 'united kingdom'
    
  else:
    return country

# %%
df3['Country'] = df3['Location'].apply(country)

# %%
df3["Country"]=df3["Country"].replace('[",,,.,-]','',regex=True)

# %%
df3["Country"].value_counts().head(10)
# Out:
# usa               139717
# canada             21662
# united kingdom     18539
# germany            17075
# spain              13262
# australia          11793
# italy              11276
# france              3526
# portugal            3391
# new zealand         3097
# Name: Country, dtype: int64

# %%
df3.head()
# Out:
#    user_id                            Location   Age         Country
# 0        1                  nyc, new york, usa   NaN             usa
# 1        2           stockton, california, usa  18.0             usa
# 2        3     moscow, yukon territory, russia   NaN          russia
# 3        4           porto, v.n.gaia, portugal  17.0        portugal
# 4        5  farnborough, hants, united kingdom   NaN  united kingdom

# %% [markdown]
# Rating Dataset

# %%
df2.rename(columns={'User-ID':'user_id','Book-Rating':'Rating'}, inplace = True)

# %%
df2.columns
# Out:
# Index(['user_id', 'ISBN', 'Rating'], dtype='object')

# %%
# Creating a dataframe by merging books and ratings dataframe

books_ratings_df = df1.merge(df2, on='ISBN')

# %%
print(books_ratings_df.shape)
books_ratings_df.head()
# Out:
# (1031136, 10)
#          ISBN           Book-Title           Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                 2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                 2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                 2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  user_id  Rating
# 0  http://images.amazon.com/images/P/0195153448.0...        2       0
# 1  http://images.amazon.com/images/P/0002005018.0...        8       5
# 2  http://images.amazon.com/images/P/0002005018.0...    11400       0
# 3  http://images.amazon.com/images/P/0002005018.0...    11676       8
# 4  http://images.amazon.com/images/P/0002005018.0...    41385       0

# %%
# Groupby on book title by counting the number of ratings
num_rating_book_df = books_ratings_df.groupby('Book-Title')['Rating'].count().reset_index()
# Renaming the column of the dataframe 
num_rating_book_df.rename(columns={'Book-Rating':'num_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
num_rating_book_df.head()
# Out:
#                                           Book-Title  Rating
# 0   A Light in the Storm: The Civil War Diary of ...       4
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4   Beyond IBM: Leadership Marketing and Finance ...       1

# %%
# Groupby on book title by taking the ratings average
avg_rating_book_df = books_ratings_df.groupby('Book-Title').mean()['Rating'].reset_index()

# Renaming the column of the dataframe
avg_rating_book_df.rename(columns={'Rating':'avg_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
avg_rating_book_df.head()
# Out:
#                                           Book-Title  avg_ratings
# 0   A Light in the Storm: The Civil War Diary of ...         2.25
# 1                              Always Have Popsicles         0.00
# 2               Apple Magic (The Collector's series)         0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...         8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...         0.00

# %%
# Creating a new dataframe by merging the number and average rating dataframes
popular_books_df = num_rating_book_df.merge(avg_rating_book_df, on='Book-Title')

# Printing the first 5 rows of the dataframe
popular_books_df.head()
# Out:
#                                           Book-Title  Rating  avg_ratings
# 0   A Light in the Storm: The Civil War Diary of ...       4         2.25
# 1                              Always Have Popsicles       1         0.00
# 2               Apple Magic (The Collector's series)       1         0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1         8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...       1         0.00

# %%
# Selecting the books which have received ratings 200 and above and arranging the average ratings in descending order
popular_books_df = popular_books_df[popular_books_df['Rating']>=200].sort_values('avg_ratings', ascending=False).head(10)

# Printing the top 10 most popular books on the basis of ratings
popular_books_df
# Out:
#                                                Book-Title  Rating  avg_ratings
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)     428     5.852804
# 80422        Harry Potter and the Goblet of Fire (Book 4)     387     5.824289
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)     278     5.737410
# 80426   Harry Potter and the Order of the Phoenix (Boo...     347     5.501441
# 60583       Ender's Game (Ender Wiggins Saga (Paperback))     249     5.409639
# 80414    Harry Potter and the Chamber of Secrets (Book 2)     556     5.183453
# 191612  The Hobbit : The Enchanting Prelude to The Lor...     281     5.007117
# 187377  The Fellowship of the Ring (The Lord of the Ri...     368     4.948370
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...     575     4.895652
# 211384     The Two Towers (The Lord of the Rings, Part 2)     260     4.880769

# %%
# Getting all the details of the top 10 most popular books

popular_books_df.merge(df1, on='Book-Title').drop_duplicates('Book-Title')
# Out:
#                                            Book-Title  Rating  avg_ratings  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)     428     5.852804
# 3        Harry Potter and the Goblet of Fire (Book 4)     387     5.824289
# 5      Harry Potter and the Sorcerer's Stone (Book 1)     278     5.737410
# 9   Harry Potter and the Order of the Phoenix (Boo...     347     5.501441
# 13      Ender's Game (Ender Wiggins Saga (Paperback))     249     5.409639
# 17   Harry Potter and the Chamber of Secrets (Book 2)     556     5.183453
# 20  The Hobbit : The Enchanting Prelude to The Lor...     281     5.007117
# 21  The Fellowship of the Ring (The Lord of the Ri...     368     4.948370
# 30  Harry Potter and the Sorcerer's Stone (Harry P...     575     4.895652
# 32     The Two Towers (The Lord of the Rings, Part 2)     260     4.880769
#
#           ISBN       Book-Author  Year-Of-Publication               Publisher  \
# 0   0439136350     J. K. Rowling                 1999              Scholastic
# 3   0439139597     J. K. Rowling                 2000              Scholastic
# 5   0590353403     J. K. Rowling                 1998              Scholastic
# 9   043935806X     J. K. Rowling                 2003              Scholastic
# 13  0312853238  Orson Scott Card                 1992               Tor Books
# 17  0439064872     J. K. Rowling                 2000              Scholastic
# 20  0345339681    J.R.R. TOLKIEN                 1986                 Del Rey
# 21  0345339703    J.R.R. TOLKIEN                 1986                 Del Rey
# 30  059035342X     J. K. Rowling                 1999  Arthur A. Levine Books
# 32  0345339711    J.R.R. TOLKIEN                 1986                 Del Rey
#
#                                           Image-URL-S  \
# 0   http://images.amazon.com/images/P/0439136350.0...
# 3   http://images.amazon.com/images/P/0439139597.0...
# 5   http://images.amazon.com/images/P/0590353403.0...
# 9   http://images.amazon.com/images/P/043935806X.0...
# 13  http://images.amazon.com/images/P/0312853238.0...
# 17  http://images.amazon.com/images/P/0439064872.0...
# 20  http://images.amazon.com/images/P/0345339681.0...
# 21  http://images.amazon.com/images/P/0345339703.0...
# 30  http://images.amazon.com/images/P/059035342X.0...
# 32  http://images.amazon.com/images/P/0345339711.0...
#
#                                           Image-URL-M  \
# 0   http://images.amazon.com/images/P/0439136350.0...
# 3   http://images.amazon.com/images/P/0439139597.0...
# 5   http://images.amazon.com/images/P/0590353403.0...
# 9   http://images.amazon.com/images/P/043935806X.0...
# 13  http://images.amazon.com/images/P/0312853238.0...
# 17  http://images.amazon.com/images/P/0439064872.0...
# 20  http://images.amazon.com/images/P/0345339681.0...
# 21  http://images.amazon.com/images/P/0345339703.0...
# 30  http://images.amazon.com/images/P/059035342X.0...
# 32  http://images.amazon.com/images/P/0345339711.0...
#
#                                           Image-URL-L
# 0   http://images.amazon.com/images/P/0439136350.0...
# 3   http://images.amazon.com/images/P/0439139597.0...
# 5   http://images.amazon.com/images/P/0590353403.0...
# 9   http://images.amazon.com/images/P/043935806X.0...
# 13  http://images.amazon.com/images/P/0312853238.0...
# 17  http://images.amazon.com/images/P/0439064872.0...
# 20  http://images.amazon.com/images/P/0345339681.0...
# 21  http://images.amazon.com/images/P/0345339703.0...
# 30  http://images.amazon.com/images/P/059035342X.0...
# 32  http://images.amazon.com/images/P/0345339711.0...

# %%
# Groupby on book author by counting the number of ratings
num_rating_author_df = books_ratings_df.groupby('Book-Author').count()['Rating'].reset_index()

# Renaming the column of the dataframe
num_rating_author_df.rename(columns={'Rating':'num_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
num_rating_author_df.head()
# Out:
#                         Book-Author  num_ratings
# 0                          D. Chiel            4
# 1                      J. D. Landis            1
# 2                       Mimma Balia            1
# 3                           'N Sync            1
# 4  142 moms from all over the world            1

# %%
# Groupby on book author by taking the ratings average
avg_rating_author_df = books_ratings_df.groupby('Book-Author').mean()['Rating'].reset_index()

# Renaming the column of the dataframe
avg_rating_author_df.rename(columns={'Rating':'avg_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
avg_rating_author_df.head()
# Out:
#                         Book-Author  avg_ratings
# 0                          D. Chiel          2.5
# 1                      J. D. Landis          0.0
# 2                       Mimma Balia          8.0
# 3                           'N Sync          0.0
# 4  142 moms from all over the world          5.0

# %%
# Creating a new dataframe by merging the number and average rating dataframes
popular_authors_df = num_rating_author_df.merge(avg_rating_author_df, on='Book-Author')

# Printing the first 5 rows of the dataframe
popular_authors_df.head()
# Out:
#                         Book-Author  num_ratings  avg_ratings
# 0                          D. Chiel            4          2.5
# 1                      J. D. Landis            1          0.0
# 2                       Mimma Balia            1          8.0
# 3                           'N Sync            1          0.0
# 4  142 moms from all over the world            1          5.0

# %%
# Selecting the authors who have received ratings 200 and above and arranging the average ratings in descending order
popular_authors_df = popular_authors_df[popular_authors_df['num_ratings']>=200].sort_values('avg_ratings', ascending=False).head(10)

# Printing the top 10 most popular authors on the basis of ratings
popular_authors_df
# Out:
#                      Book-Author  num_ratings  avg_ratings
# 9640              Bill Watterson          550     5.561818
# 5678   Antoine de Saint-ExupÃ©ry          278     5.553957
# 40388              J. K. Rowling         2908     5.385832
# 72430               Nick Bantock          270     5.292593
# 40547           J. R. R. Tolkien          978     5.165644
# 24643                  Dr. Seuss          371     5.121294
# 19166               Daniel Quinn          264     5.045455
# 36574                 Harper Lee          534     4.728464
# 40805             J.R.R. Tolkien          285     4.694737
# 56653                 LOIS LOWRY          310     4.638710

# %%
# Getting all the details of the top 10 most popular authors

popular_authors_df.merge(df1, on='Book-Author').drop_duplicates('Book-Author')
# Out:
#                    Book-Author  num_ratings  avg_ratings        ISBN  \
# 0               Bill Watterson          550     5.561818  0836218256
# 42   Antoine de Saint-ExupÃ©ry          278     5.553957  0156528207
# 63               J. K. Rowling         2908     5.385832  059035342X
# 141               Nick Bantock          270     5.292593  0811802981
# 159           J. R. R. Tolkien          978     5.165644  8445071408
# 333                  Dr. Seuss          371     5.121294  039480001X
# 373               Daniel Quinn          264     5.045455  0553375407
# 392                 Harper Lee          534     4.728464  0446310786
# 407             J.R.R. Tolkien          285     4.694737  0618126988
# 453                 LOIS LOWRY          310     4.638710  0440219078
#
#                                             Book-Title  Year-Of-Publication  \
# 0                  Something Under the Bed Is Drooling                 1988
# 42                                   The Little Prince                 1968
# 63   Harry Potter and the Sorcerer's Stone (Harry P...                 1999
# 141  The Golden Mean: In Which the Extraordinary Co...                 1993
# 159  El Senor De Los Anillos: LA Comunidad Del Anil...                 2001
# 333                                 The Cat in the Hat                 1957
# 373       Ishmael: An Adventure of the Mind and Spirit                 1995
# 392                              To Kill a Mockingbird                 1988
# 407                                   The Silmarillion                 2001
# 453                 The Giver (21st Century Reference)                 1994
#
#                                 Publisher  \
# 0               Andrews McMeel Publishing
# 42                               Harcourt
# 63                 Arthur A. Levine Books
# 141                       Chronicle Books
# 159                             Minotauro
# 333  Random House Books for Young Readers
# 373                                Bantam
# 392            Little Brown &amp; Company
# 407                      Houghton Mifflin
# 453                            Laure Leaf
#
#                                            Image-URL-S  \
# 0    http://images.amazon.com/images/P/0836218256.0...
# 42   http://images.amazon.com/images/P/0156528207.0...
# 63   http://images.amazon.com/images/P/059035342X.0...
# 141  http://images.amazon.com/images/P/0811802981.0...
# 159  http://images.amazon.com/images/P/8445071408.0...
# 333  http://images.amazon.com/images/P/039480001X.0...
# 373  http://images.amazon.com/images/P/0553375407.0...
# 392  http://images.amazon.com/images/P/0446310786.0...
# 407  http://images.amazon.com/images/P/0618126988.0...
# 453  http://images.amazon.com/images/P/0440219078.0...
#
#                                            Image-URL-M  \
# 0    http://images.amazon.com/images/P/0836218256.0...
# 42   http://images.amazon.com/images/P/0156528207.0...
# 63   http://images.amazon.com/images/P/059035342X.0...
# 141  http://images.amazon.com/images/P/0811802981.0...
# 159  http://images.amazon.com/images/P/8445071408.0...
# 333  http://images.amazon.com/images/P/039480001X.0...
# 373  http://images.amazon.com/images/P/0553375407.0...
# 392  http://images.amazon.com/images/P/0446310786.0...
# 407  http://images.amazon.com/images/P/0618126988.0...
# 453  http://images.amazon.com/images/P/0440219078.0...
#
#                                            Image-URL-L
# 0    http://images.amazon.com/images/P/0836218256.0...
# 42   http://images.amazon.com/images/P/0156528207.0...
# 63   http://images.amazon.com/images/P/059035342X.0...
# 141  http://images.amazon.com/images/P/0811802981.0...
# 159  http://images.amazon.com/images/P/8445071408.0...
# 333  http://images.amazon.com/images/P/039480001X.0...
# 373  http://images.amazon.com/images/P/0553375407.0...
# 392  http://images.amazon.com/images/P/0446310786.0...
# 407  http://images.amazon.com/images/P/0618126988.0...
# 453  http://images.amazon.com/images/P/0440219078.0...

# %% [markdown]
# ### Top 10 most popular publishers on the basis of ratings

# %%
# Groupby on book publisher by counting the number of ratings
num_rating_pub_df = books_ratings_df.groupby('Publisher').count()['Rating'].reset_index()

# Renaming the column of the dataframe
num_rating_pub_df.rename(columns={'Rating':'num_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
num_rating_pub_df.head()
# Out:
#                                       Publisher  num_ratings
# 0                           Editions P. Terrail            1
# 1                               Tri-State Press            1
# 2                                       'K' Pub            1
# 3  (3 Queen Sq., WC1N 3AU), Faber and Faber Ltd            1
# 4             (49 Poland St., W.1), BPC Unit 75            1

# %%
# Groupby on book publisher by taking the ratings average
avg_rating_pub_df = books_ratings_df.groupby('Publisher').mean()['Rating'].reset_index()

# Renaming the column of the dataframe
avg_rating_pub_df.rename(columns={'Rating':'avg_ratings'}, inplace=True)

# Printing the first 5 rows of the dataframe
avg_rating_pub_df.head()
# Out:
#                                       Publisher  avg_ratings
# 0                           Editions P. Terrail         10.0
# 1                               Tri-State Press          6.0
# 2                                       'K' Pub          8.0
# 3  (3 Queen Sq., WC1N 3AU), Faber and Faber Ltd          0.0
# 4             (49 Poland St., W.1), BPC Unit 75          0.0

# %%
# Creating a new dataframe by merging the number and average rating dataframes
popular_publishers_df = num_rating_pub_df.merge(avg_rating_pub_df, on='Publisher')

# Printing the first 5 rows of the dataframe
popular_publishers_df.head()
# Out:
#                                       Publisher  num_ratings  avg_ratings
# 0                           Editions P. Terrail            1         10.0
# 1                               Tri-State Press            1          6.0
# 2                                       'K' Pub            1          8.0
# 3  (3 Queen Sq., WC1N 3AU), Faber and Faber Ltd            1          0.0
# 4             (49 Poland St., W.1), BPC Unit 75            1          0.0

# %%
# Selecting the publishers who have received ratings 200 and above and arranging the average ratings in descending order
popular_publishers_df = popular_publishers_df[popular_publishers_df['num_ratings']>=200].sort_values('avg_ratings', ascending=False).head(10)

# Printing the top 10 most popular publishers on the basis of ratings
popular_publishers_df
# Out:
#                        Publisher  num_ratings  avg_ratings
# 5400              Five Star (ME)          207     7.884058
# 14873                   TokyoPop          205     6.570732
# 14874                   Tokyopop          310     6.277419
# 3725                   DC Comics          529     5.913043
# 1201                 Authorhouse          224     5.285714
# 15089                   Tusquets          274     4.861314
# 1008      Arthur A. Levine Books          629     4.786963
# 758    Andrews McMeel Publishing         2589     4.685207
# 2808              Celestial Arts          247     4.672065
# 16444         Writers Club Press          293     4.668942

# %%
# Getting all the details of the top 10 most popular publishers

popular_publishers_df.merge(df1, on='Publisher').drop_duplicates('Publisher')
# Out:
#                       Publisher  num_ratings  avg_ratings        ISBN  \
# 0                Five Star (ME)          207     7.884058  1594140812
# 183                    TokyoPop          205     6.570732  1591822580
# 285                    Tokyopop          310     6.277419  1591824095
# 427                   DC Comics          529     5.913043  1401201172
# 584                 Authorhouse          224     5.285714  1418447293
# 741                    Tusquets          274     4.861314  8472238822
# 903      Arthur A. Levine Books          629     4.786963  059035342X
# 923   Andrews McMeel Publishing         2589     4.685207  0740700235
# 1490             Celestial Arts          247     4.672065  0890877564
# 1604         Writers Club Press          293     4.668942  0595168442
#
#                                              Book-Title           Book-Author  \
# 0                                        Becoming Maren           Africa Fine
# 183                                   Chobits (Chobits)                 Clamp
# 285                                     Chobits, Book 8                 Clamp
# 427   League of Extraordinary Gentlemen, Vol. 2 (Comic)            Alan Moore
# 584                         The Thoughts of an Emigrant  Albert Schwarzenbach
# 741   Tu Nombre Escrito En El Agua (La Sonrisa Verti...   Irene Gonzalez Frei
# 903   Harry Potter and the Sorcerer's Stone (Harry P...         J. K. Rowling
# 923   Life Messages: Inspiration For The Woman's Spirit     Josephine Carlton
# 1490       Totally Muffins Cookbook (Totally Cookbooks)         Helene Siegel
# 1604                                          Cigar Box           Wilbur Witt
#
#       Year-Of-Publication                                        Image-URL-S  \
# 0                    2003  http://images.amazon.com/images/P/1594140812.0...
# 183                  2003  http://images.amazon.com/images/P/1591822580.0...
# 285                  2003  http://images.amazon.com/images/P/1591824095.0...
# 427                  2003  http://images.amazon.com/images/P/1401201172.0...
# 584                  2004  http://images.amazon.com/images/P/1418447293.0...
# 741                  2002  http://images.amazon.com/images/P/8472238822.0...
# 903                  1999  http://images.amazon.com/images/P/059035342X.0...
# 923                  2002  http://images.amazon.com/images/P/0740700235.0...
# 1490                 1995  http://images.amazon.com/images/P/0890877564.0...
# 1604                 2001  http://images.amazon.com/images/P/0595168442.0...
#
#                                             Image-URL-M  \
# 0     http://images.amazon.com/images/P/1594140812.0...
# 183   http://images.amazon.com/images/P/1591822580.0...
# 285   http://images.amazon.com/images/P/1591824095.0...
# 427   http://images.amazon.com/images/P/1401201172.0...
# 584   http://images.amazon.com/images/P/1418447293.0...
# 741   http://images.amazon.com/images/P/8472238822.0...
# 903   http://images.amazon.com/images/P/059035342X.0...
# 923   http://images.amazon.com/images/P/0740700235.0...
# 1490  http://images.amazon.com/images/P/0890877564.0...
# 1604  http://images.amazon.com/images/P/0595168442.0...
#
#                                             Image-URL-L
# 0     http://images.amazon.com/images/P/1594140812.0...
# 183   http://images.amazon.com/images/P/1591822580.0...
# 285   http://images.amazon.com/images/P/1591824095.0...
# 427   http://images.amazon.com/images/P/1401201172.0...
# 584   http://images.amazon.com/images/P/1418447293.0...
# 741   http://images.amazon.com/images/P/8472238822.0...
# 903   http://images.amazon.com/images/P/059035342X.0...
# 923   http://images.amazon.com/images/P/0740700235.0...
# 1490  http://images.amazon.com/images/P/0890877564.0...
# 1604  http://images.amazon.com/images/P/0595168442.0...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Creating a dataframe of authors having written maximum number of books
top_authors = pd.DataFrame(df1['Book-Author'].value_counts()[:10]).reset_index()

# Renaming the columns of the dataframe
top_authors.rename(columns = {'index':'Author', 'Book-Author':'Count'}, inplace = True)

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x = 'Author', y = 'Count', data = top_authors, palette="Purples_r")

# Defining the title, xticks rotation and x and y labels
plt.xticks(rotation=45)
figure.set(title='Authors having written maximum number of books')
figure.set(xlabel='Authors', ylabel='Number of books written')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 authors who have written maximum number of books.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart, we found out that Agatha Christie have written maximum number of books followed by William Shakespeare and Stephen King.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Creating a dataframe of years in which maximum number of books were published
top_years = pd.DataFrame(df1['Year-Of-Publication'].value_counts().head(10)).reset_index()

# Renaming the columns of the dataframe
top_years.rename(columns = {'index':'publication_year', 'Year-Of-Publication':'Count'}, inplace=True)

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x='publication_year', y='Count', data=top_years, order=top_years.sort_values('Count', ascending=False).publication_year,palette="gist_gray")

# Defining the title, xticks rotation and x and y labels
figure.set(title='Years having maximum books publications')
figure.set(xlabel='Years', ylabel='Number of books published')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 years in which maximum number of books were published.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart, we found out that 2002, 2001 and 1999 are the top years in which maximum number of books were published

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Creating a dataframe of publishers having published maximum number of books
top_publishers = pd.DataFrame(df1['Publisher'].value_counts()[:10]).reset_index()

# Renaming the columns of the dataframe
top_publishers.rename(columns = {'index':'Publisher', 'Publisher':'Count'}, inplace=True)

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x='Publisher', y='Count', data=top_publishers,palette="mako")

# Defining the title, xticks rotation and x and y labels
plt.xticks(rotation=45)
figure.set(title='Publishers having published maximum number of books')
figure.set(xlabel='Publishers', ylabel='Number of books published')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 publishers who have published maximum number of books.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Harlequin published maximum number of books.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Creating a dataframe of the titles repeated maximum number of times
top_titles = pd.DataFrame(df1['Book-Title'].value_counts()[:10]).reset_index()

# Renaming the columns of the dataframe
top_titles.rename(columns = {'index':'Book-Title', 'Book-Title':'Count'}, inplace = True)

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x = 'Book-Title', y = 'Count', data = top_titles, palette="OrRd_r")

# Defining the title, xticks rotation and x and y labels
plt.xticks(rotation=45)
figure.set(title='Book titles repeated for the maximum number of times')
figure.set(xlabel='Book Titles', ylabel='Number of times book title repeated')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 titles of the books repeated for maximum number of times

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Selected Poems are the most frequent title of the books.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Creating a dataframe of the countries where maximum number of users are based
top_countries = pd.DataFrame(df3['Country'].value_counts()[:10]).reset_index()

# Renaming the columns of the dataframe
top_countries.rename(columns = {'index':'Country', 'Country':'Count'}, inplace=True)

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x='Country', y='Count', data=top_countries, palette="Set3")

# Defining the title and x and y labels
figure.set(title='Countries where maximum number of users are based from')
figure.set(xlabel='Countries', ylabel='Number of users')
plt.xticks(rotation=45)

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 countries where maximum number of the users are based from.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Maximum number of the users are from USA.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Defining the plot size
fig,axes=plt.subplots(nrows=1,ncols=2,constrained_layout=True,figsize=(10,4))

# Plotting a distribution plot

figure1 = sns.histplot(data=df3['Age'],bins=20,kde=True,ax=axes[0])
# Defining the title and x and y labels
figure1.set(title='Distribution of the age of the users reading books')
figure1.set(xlabel='Age')

# Defining the x-axis data range
plt.xlim(0, 120)

#Plotting a boxplot
sns.boxplot(x='Age',data=df3)

# Displaying the graph
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find distribution of the user's age reading books

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Distribution of the user's age is positively skewed and have a lot of outliers, and it seems that user's age are fitted incorrectly in the dataset.
#
# 50% of data of user's age lies between 25 to 45.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Creating a dataframe of the users who have maximum number of times on the books 
top_users = pd.DataFrame(df2['User-ID'].value_counts()[:10]).reset_index()

# Renaming the columns of the dataframe
top_users.rename(columns = {'index':'User-ID', 'User-ID':'Count'}, inplace=True)

# %%
top_users.head()
# Out:
#    User-ID  Count
# 0    11676  13602
# 1   198711   7550
# 2   153662   6109
# 3    98391   5891
# 4    35859   5850

# %%
df3.head()
# Out:
#    user_id                            Location   Age         Country
# 0        1                  nyc, new york, usa   NaN             usa
# 1        2           stockton, california, usa  18.0             usa
# 2        3     moscow, yukon territory, russia   NaN          russia
# 3        4           porto, v.n.gaia, portugal  17.0        portugal
# 4        5  farnborough, hants, united kingdom   NaN  united kingdom

# %%
# Defining the plot size
plt.figure(figsize=(10,5))

# Plotting a bargraph
figure = sns.barplot(x='User-ID', y='Count', data=top_users, order=top_users.sort_values('Count', ascending=False)['User-ID'], palette="pink")

# Defining the title and x and y labels
figure.set(title='Users having rated maximum number of times on the books')
figure.set(xlabel='User IDs', ylabel='Number of time ratings given')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 users who have rated maximum number of times on the books

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# User with User ID 11676 is the most frequent book rater.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Defining the plot size
plt.figure(figsize=(10,4))

# Plotting a bargraph
figure = sns.countplot(x=df2['Book-Rating'],palette="YlOrBr_r")

# Defining the title and x and y labels
figure.set(title='Number of ratings received on the books')
figure.set(xlabel='Ratings', ylabel='Number of ratings')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the distibution of ratings received on the books.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 0 is the most frequent rating received on the book, it is either received 0 rating or no rating by the user.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Creating a dataframe with no 0 ratings
rating = df2[df2['Book-Rating']!=0]

# Defining the plot size
plt.figure(figsize=(10,4))

# Plotting a bargraph
figure = sns.countplot(x = rating['Book-Rating'], data=rating, palette="Wistia_r")

# Defining the title and x and y labels
figure.set(title='Number of ratings received on the books')
figure.set(xlabel='Ratings', ylabel='Number of ratings')

# Displaying the graph
plt.show(figure)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To Find the number of different ratings received on the books excluding 0 rating

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After excluding 0 rating, 8 is the most frequent rating received on the books.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Ploting the bargraph of the top 10 most popular books
popular_books_df.plot(x='Book-Title', title='Top 10 books on the basis of ratings',
                      legend=True, kind='bar', colormap='Dark2', figsize=(18,6),
                      secondary_y='avg_ratings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the top 10 books on the basis of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Book "Harry Potter and the Prisoner of Azkaban(Book 3)" has maximum Average rating and Number of rating are more 400.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Ploting the bargraph of the top 10 most popular authors

popular_authors_df.plot(x='Book-Author', title='Top 10 authors on the basis of ratings',
                      legend=True, kind='bar', colormap='Dark2', figsize=(18,6),
                      secondary_y='avg_ratings', rot=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the top 10 authors on the basis of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Author Bill Watterson has maximum average rating.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Ploting the bargraph of the top 10 most popular publishers

popular_publishers_df.plot(x='Publisher', title='Top 10 publishers on the basis of ratings',
                      legend=True, kind='bar', colormap='Dark2', figsize=(18,6),
                      secondary_y='avg_ratings', rot=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find top 10 publishers on the basis of ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Five Star (ME) publisher has maximum average rating(approx 8).

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Hypothesis 1 : Average rating by the user is 7.5
#
# Hypothesis 2 : User's Age is distributed normally.
#
# Hypothesis 3 : Median of production year is 2004.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Average rating by the user is 7.5
#
# Null Hypothesis H0 : ℳ = 7.5 , Mean rating is 7.5
#
# Alternative Hypothesis H1 : ℳ != 7.5 , Mean rating is not 7.5

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Statistical Test to obtain P-Value
from scipy import stats 
from scipy.stats import ttest_1samp

#let's take the sample mean and population mean
pop_mean = 3
sample = popular_books_df['num_ratings']
t_stat, p_value = ttest_1samp(sample, pop_mean)
print("T-statistic value: ", t_stat)  
print("P-Value: ", p_value)

# criteria for null hypothesis to reject, Take level of significance(alpha) = 0.05
if p_value <= 0.05:
  print("Reject Null Hypothesis")
else :
  print(" Fail to reject Null hypothesis")
# Out:
# T-statistic value:  9.971477398715892
# P-Value:  3.6643108645308443e-06
# Reject Null Hypothesis

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# We chose t test for one sample (two-tailed test) to check if the average rating given by users is 7.5 or not.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The one-sample t-test is a statistical hypothesis test used to determine whether an unknown population mean is different from a specific value, for our dataset unknown population mean is average user rating and specific value is 7.5.

# %% [markdown]
# **INFERENCE** : Since p_value obtained is less than level of significance (0.05). Hence we reject the null hypothesis and conclude that avergae rating given by users is not 7.5.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Hypothesis 2 : User's Age is distributed normally.
#
# Null Hypothesis H0 : User's Age has Gaussian distribution.
#
# Alternative Hypothesis H1 : User's Age does not have Gaussian distribution.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
# Perform Statistical Test to obtain P-Value
from scipy.stats import shapiro
sample = df3["Age"]
stat, p_value = shapiro(sample)
print('stat=%.3f, p_value=%.3f' % (stat, p_value))
if p_value > 0.05:
 print('Probably Gaussian')
else:
 print('Probably not Gaussian')
# Out:
# stat=nan, p_value=1.000
# Probably Gaussian

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Here I have used Shapiro - Wilk test to check if Distribution of User's Age is distributed normally or not.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Shapiro-Wilk Test is the appropriate test for testing the normality of data. it assumes that Observations in each sample are independent and identically distributed (iid).

# %% [markdown]
# INFERENCE : Since p value is 1.00 which is greater than level of significance 0.05, hence we fail to reject null hypothesis. And conclude that distribution of User's Age is probably normal.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Hypothesis 3 : Median of production year is 2004.**
#
# Null hypothesis H0 : Median of production year is 2004.
#
# Alternative hypothesis H1 : Median of production year is not 2004.

# %%
import numpy as np
from scipy.stats import wilcoxon as wil

sample = np.array(df1["Year-Of-Publication"].dropna())
med0 = 2004

W, p = wil(sample - med0, correction = False, mode = 'approx')

print("W = %.1f, p-value = %.3f" % (W, p))
# Out:
# W = 1856790.5, p-value = 0.000

# %% [markdown]
# We chose one-sample Wilcoxon signed rank test (two-tailed test) to check if the Median of production year is 2004 or not.

# %% [markdown]
# Why did you choose the specific statistical test?
#
# One sample Wilcoxon Non Parametric Hypothesis Test is a rank-based test and it compares the standard value with a hypothesized median, for our dataset, unknown population median is Median production year and hypothesized median is 2004.
#
# INFERENCE : Since p_value obtained is less than level of significance (0.05). Hence we reject the null hypothesis and conclude that median production year is not 2004.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
# fill null values of the age column of users data as age contains outliers so we can use median
df3["Age"].fillna(df3.Age.median(),inplace=True)

# %%
# filling the null values with median values as there are outliers in Publication Year column
df1['Year-Of-Publication'].fillna(round(df1['Year-Of-Publication'].median()),inplace=True)

# %%
# filling null values for the column Author and Publisher
# as we have only very few null values 1 and 2 only so we act fill those values with other 
df1["Book-Author"].fillna("other", inplace = True)  
df1["Publisher"].fillna("other", inplace = True)

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# * Fill the missing values with median since the column contain outilers.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
Q3,Q1 = np.percentile(df3['Age'],[75,25])
#Calculating Inter Quartile Range
IQR = Q3-Q1
#Fixing Boundaries for outliers
max = Q3+(1.5*IQR)
min = Q1-(1.5*IQR)
df3["Age"] = np.where(df3["Age"] > max, max, df3['Age'])
df3["Age"] = np.where(df3["Age"] < min, min, df3['Age'])

# %%
# chceking the outliers again
fig = plt.figure(figsize=(6,4))
sns.boxplot(x='Age',data=df3)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# * We can conclude that the Outliers has been handeled smoothly and now data don't have any outliers.

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# * We used IQR method to fill the right side outliers with maximum value and Left side outliers with the minimum value.

# %% [markdown]
# ## **7. Popularity Based Approach**
#
# * The main idea behind Popularity Based Approach is to recomend the books which are popular, the popularity can be calculated on the basis of ratings.

# %%
def popularity_approach(df,number_of_top_book=50):
    # first we have groupy with Title and Rating as we would recomend popularity on the these columns  
    rating_counts=df.groupby("Book-Title").count()["Rating"].reset_index()
    # counting the number of ratings that particular Title has got
    rating_counts.rename(columns={"Rating":"num_of_ratings"},inplace=True)
    
    # calculating average rating
    rating_avg=df.groupby("Book-Title")["Rating"].mean().reset_index()
    rating_avg.rename(columns={"Rating":"average_rating"},inplace=True)
    
    df_popular_books=rating_counts.merge(rating_avg,on="Book-Title")

    # average rating can be misguiding as they may be biased to number of ratings
    # so taking account of number of ratings for particular title
    # therefore  creating a function for calculating meaningfull average rating
    mean_avg_rating=df_popular_books["average_rating"].mean()
    total_ratings=df_popular_books["num_of_ratings"].quantile(0.90)
    def weighted_rate(df):
        number_of_rating_vector=df["num_of_ratings"]
        average_rating_vector=df["average_rating"]
        
        return ((number_of_rating_vector*average_rating_vector) + (total_ratings*mean_avg_rating)) / (number_of_rating_vector+total_ratings)
    
    
    # checking only for books which got more than 
    df_popular_books=df_popular_books[df_popular_books["num_of_ratings"] >=100]
    # calculating popularity of books using weighted_rate
    df_popular_books["popularity"]=df_popular_books.apply(weighted_rate,axis=1)
    # sorting the books by its popularity in decending order
    df_popular_books=df_popular_books.sort_values(by="popularity",ascending=False)
    # returning the top n books 
    return df_popular_books[["Book-Title","num_of_ratings","average_rating","popularity"]].reset_index(drop=True).head(number_of_top_book)

# %%
# top 20 popular books
top_20=pd.DataFrame(popularity_approach(books_ratings_df,20))
top_20
# Out:
#                                            Book-Title  num_of_ratings  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)             428
# 1        Harry Potter and the Goblet of Fire (Book 4)             387
# 2                                   The Little Prince             141
# 3      Harry Potter and the Sorcerer's Stone (Book 1)             278
# 4   Harry Potter and the Order of the Phoenix (Boo...             347
# 5       Ender's Game (Ender Wiggins Saga (Paperback))             249
# 6    Harry Potter and the Chamber of Secrets (Book 2)             556
# 7                     The Perks of Being a Wallflower             104
# 8   The Hobbit : The Enchanting Prelude to The Lor...             281
# 9   The Fellowship of the Ring (The Lord of the Ri...             368
# 10  Harry Potter and the Sorcerer's Stone (Harry P...             575
# 11                 The Giver (21st Century Reference)             179
# 12     The Two Towers (The Lord of the Rings, Part 2)             260
# 13       Ishmael: An Adventure of the Mind and Spirit             162
# 14                            Interpreter of Maladies             136
# 15              Anne Frank: The Diary of a Young Girl             142
# 16                   Charlotte's Web (Trophy Newbery)             129
# 17                              The Other Boleyn Girl             159
# 18                              To Kill a Mockingbird             510
# 19                                  The Da Vinci Code             898
#
#     average_rating  popularity
# 0         5.852804    5.805129
# 1         5.824289    5.772160
# 2         5.815603    5.677236
# 3         5.737410    5.667477
# 4         5.501441    5.449805
# 5         5.409639    5.340746
# 6         5.183453    5.154940
# 7         5.144231    5.002081
# 8         5.007117    4.955663
# 9         4.948370    4.909949
# 10        4.895652    4.871531
# 11        4.916201    4.839951
# 12        4.880769    4.828580
# 13        4.907407    4.823852
# 14        4.897059    4.798818
# 15        4.852113    4.759939
# 16        4.782946    4.685522
# 17        4.761006    4.682114
# 18        4.700000    4.675495
# 19        4.642539    4.628984

# %% [markdown]
# ## **8. Collaborative Filtering Approaches**
#
# In Collaborative Filtering we make predictions of the taste or the interests of the user based on the other similar users behaviour (which is called collaborative) .The simple understanding is that if a person P1 have similar opinion with person P2 , then if person P1 is reading Harry Potter books then person P2 may also read Harry Potter books.
#
# Collaborative Filtering has mainly two implimentaion strategies
#  *   Model Based
#  *   Memory Based
#
# we will use following approaches
#   *  User_based Collaborative Filtering and
#   *  Item_based Collaborative Filtering
#
#
#  Content Based Filtering
#
#
# *  Model based Collaborative Filtering Approach
#    * Singular value decomposition(SVD)
#    * Non-Negetive Matrix Factorisation(NMF)

# %% [markdown]
# ### **User Based Collaborative Filtering**
#
# *  In this technique we try to predict on basis of what user may like based on the ratings that they had given to the items. In simple words here we try to identify the neighbouring users on the basis of similarity of active users and then scoring of the items is calculated on the basis of those neighbour users.

# %%
# Drop users who have given less number of votings 
# we will drop the users where the number of votes are less than 100
new_df=books_ratings_df[books_ratings_df['user_id'].map(books_ratings_df['user_id'].value_counts()) > 100] 

# creating a pivot tables consisting user related information
users_info=new_df.pivot_table(index=["user_id"],columns=["Book-Title"],values="Rating")
users_info.fillna(0,inplace=True)

# %%
users_info.head()
# Out:
# Book-Title   A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title   Always Have Popsicles   Apple Magic (The Collector's series)  \
# user_id
# 254                            0.0                                    0.0
# 507                            0.0                                    0.0
# 882                            0.0                                    0.0
# 1424                           0.0                                    0.0
# 1435                           0.0                                    0.0
#
# Book-Title   Beyond IBM: Leadership Marketing and Finance for the 1990s  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title   Clifford Visita El Hospital (Clifford El Gran Perro Colorado)  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title   Dark Justice   Deceived  \
# user_id
# 254                   0.0        0.0
# 507                   0.0        0.0
# 882                   0.0        0.0
# 1424                  0.0        0.0
# 1435                  0.0        0.0
#
# Book-Title   Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title   Final Fantasy Anthology: Official Strategy Guide (Brady Games)  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title   Flight of Fancy: American Heiresses (Zebra Ballad Romance)  ...  \
# user_id                                                                  ...
# 254                                                       0.0            ...
# 507                                                       0.0            ...
# 882                                                       0.0            ...
# 1424                                                      0.0            ...
# 1435                                                      0.0            ...
#
# Book-Title  Ã?ngeles fugaces (Falling Angels)  Ã?Â?. Kolumnen.  \
# user_id
# 254                                       0.0              0.0
# 507                                       0.0              0.0
# 882                                       0.0              0.0
# 1424                                      0.0              0.0
# 1435                                      0.0              0.0
#
# Book-Title  Ã?Â?ber das Fernsehen.  Ã?Â?ber die Freiheit.  \
# user_id
# 254                            0.0                    0.0
# 507                            0.0                    0.0
# 882                            0.0                    0.0
# 1424                           0.0                    0.0
# 1435                           0.0                    0.0
#
# Book-Title  Ã?Â?ber die Pflicht zum Ungehorsam gegen den Staat.  \
# user_id
# 254                                                       0.0
# 507                                                       0.0
# 882                                                       0.0
# 1424                                                      0.0
# 1435                                                      0.0
#
# Book-Title  Ã?Â?berraschung am Valentinstag.  Ã?Â?lpiraten.  \
# user_id
# 254                                      0.0            0.0
# 507                                      0.0            0.0
# 882                                      0.0            0.0
# 1424                                     0.0            0.0
# 1435                                     0.0            0.0
#
# Book-Title  Ã?Â?rger mit Produkt X. Roman.  Ã?Â?stlich der Berge.  \
# user_id
# 254                                    0.0                    0.0
# 507                                    0.0                    0.0
# 882                                    0.0                    0.0
# 1424                                   0.0                    0.0
# 1435                                   0.0                    0.0
#
# Book-Title  Ã?Â?thique en toc
# user_id
# 254                       0.0
# 507                       0.0
# 882                       0.0
# 1424                      0.0
# 1435                      0.0
#
# [5 rows x 178335 columns]

# %%
def choice_of_users(id):
    
    user_favourite=new_df[new_df["user_id"]==id].sort_values(["Rating"],ascending=False)[0:10]
    return user_favourite

def user_based_collaborative(new_df,user_id):
    if user_id not in new_df["user_id"].values:
        print("USER NOT FOUND")
        
        
    else:
        user_index=np.where(users_info.index==user_id)[0][0]
        similar=cosine_similarity(users_info)
        similar_users_list=list(enumerate(similar[user_index]))
        similar_users_list = sorted(similar_users_list,key = lambda x:x[1],reverse=True)[0:10]
    
        record_of_users=[]
    
        for ind in similar_users_list:
                data=books_ratings_df[books_ratings_df["user_id"]==users_info.index[ind[0]]]
                record_of_users.extend(list(data.drop_duplicates("user_id")["user_id"].values))
        
    return record_of_users

def common(df,users_list,user_id):
    temp1=new_df[df["user_id"]==user_id]
    suggested_books=[]
    users_list=list(users_list)
    for id in users_list:
        temp2=df[(df["user_id"]==id)]
        all_books=temp2.loc[~temp2["Book-Title"].isin(temp1["Book-Title"]),:]
        all_books=all_books.sort_values(["Rating"],ascending=False)[0:10]
        suggested_books.extend(all_books["Book-Title"].values)
        
    return suggested_books[0:10]

# %%
# taking any random user_id
import random
random_user_id=random.choice(new_df["user_id"].values)
# showing users choice based on history
user_choice=pd.DataFrame(choice_of_users(random_user_id))
# subseting users favourite from users choice
user_favorite=choice_of_users(random_user_id)
n=len(user_choice["Book-Title"].values)
print(f"USER: {random_user_id} ")
# Out:
# USER: 44845

# %%
user_favorite
# Out:
#               ISBN                                         Book-Title  \
# 178277  0440241812                         Shopaholic Takes Manhattan
# 724893  0528831143                             Atlas of World History
# 724913  0916773124  Welcoming Your Second Baby (Family &amp; Child...
# 725037  1558533265  When You Lick a Slug, Your Tongue Goes Numb: K...
# 724911  0786864206     The Amazing True Story of a Teenage Single Mom
# 72454   0451187903                              Sense and Sensibility
# 644341  0425125483                                         Rendezvous
# 673962  0590446711                                             Rascal
# 122185  0373250290           Carrie Pilby (Red Dress Ink (Paperback))
# 551578  0679762094  Aman: The Story of a Somali Girl As Told to Vi...
#
#                 Book-Author  Year-Of-Publication            Publisher  \
# 178277      SOPHIE KINSELLA                 2004      Dell Publishing
# 724893         Rand Mcnally                 1984         Rand Mcnally
# 724913         Vicki Lansky                 1990        Book Peddlers
# 725037     H. Jackson Brown                 1995  Rutledge Hill Press
# 724911    Katherine Arnoldi                 1998             Hyperion
# 72454           Jane Austen                 1995          Signet Book
# 644341      Serena Richards                 1991    Berkley Pub Group
# 673962       Sterling North                 2002       Scholastic Inc
# 122185        Caren Lissner                 2003        Red Dress Ink
# 551578  Virginia Lee Barnes                 1995    Vintage Books USA
#
#                                               Image-URL-S  \
# 178277  http://images.amazon.com/images/P/0440241812.0...
# 724893  http://images.amazon.com/images/P/0528831143.0...
# 724913  http://images.amazon.com/images/P/0916773124.0...
# 725037  http://images.amazon.com/images/P/1558533265.0...
# 724911  http://images.amazon.com/images/P/0786864206.0...
# 72454   http://images.amazon.com/images/P/0451187903.0...
# 644341  http://images.amazon.com/images/P/0425125483.0...
# 673962  http://images.amazon.com/images/P/0590446711.0...
# 122185  http://images.amazon.com/images/P/0373250290.0...
# 551578  http://images.amazon.com/images/P/0679762094.0...
#
#                                               Image-URL-M  \
# 178277  http://images.amazon.com/images/P/0440241812.0...
# 724893  http://images.amazon.com/images/P/0528831143.0...
# 724913  http://images.amazon.com/images/P/0916773124.0...
# 725037  http://images.amazon.com/images/P/1558533265.0...
# 724911  http://images.amazon.com/images/P/0786864206.0...
# 72454   http://images.amazon.com/images/P/0451187903.0...
# 644341  http://images.amazon.com/images/P/0425125483.0...
# 673962  http://images.amazon.com/images/P/0590446711.0...
# 122185  http://images.amazon.com/images/P/0373250290.0...
# 551578  http://images.amazon.com/images/P/0679762094.0...
#
#                                               Image-URL-L  user_id  Rating
# 178277  http://images.amazon.com/images/P/0440241812.0...    44845      10
# 724893  http://images.amazon.com/images/P/0528831143.0...    44845      10
# 724913  http://images.amazon.com/images/P/0916773124.0...    44845      10
# 725037  http://images.amazon.com/images/P/1558533265.0...    44845      10
# 724911  http://images.amazon.com/images/P/0786864206.0...    44845      10
# 72454   http://images.amazon.com/images/P/0451187903.0...    44845      10
# 644341  http://images.amazon.com/images/P/0425125483.0...    44845      10
# 673962  http://images.amazon.com/images/P/0590446711.0...    44845      10
# 122185  http://images.amazon.com/images/P/0373250290.0...    44845      10
# 551578  http://images.amazon.com/images/P/0679762094.0...    44845       9

# %%
# getting user based data for particular random user id
user_based=user_based_collaborative(new_df,random_user_id)
# getting recomended books for that particular random user id
book_suggesions_user=common(new_df,user_based,random_user_id)
# ceating a dataframe to store the results
book_suggesions_user=pd.DataFrame(book_suggesions_user,columns=["Book-Title"])
book_suggesions_user
# Out:
#                                                Title
# 0                            Joshua in the Holy Land
# 1                                       The Shepherd
# 2                            JOSHUA AND THE CHILDREN
# 3  Chicken Soup for the Soul (Chicken Soup for th...
# 4  God's the One Who Thought of It First (Happy D...
# 5  A 5th Portion of Chicken Soup for the Soul : 1...
# 6  A 2nd Helping of Chicken Soup for the Soul: 10...
# 7  The Time Trap:  The New Version of the Classic...
# 8                          Everyday English Handbook
# 9                       Willy Whyner, Cloud Designer

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
